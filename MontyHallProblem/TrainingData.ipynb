# %%
d = [1, 3, 7]
d[2] = 11
print(d)
# Out:
# [1, 3, 11]

# %% [markdown]
# # Title
# some stuf
#
# ## First point
#
# code example
# ```
# x = 3
# ```

# %%
d
# Out:
# [1, 3, 11]

# %%
dir()
# Out:
# ['In',
#  'Out',
#  '_',
#  '_11',
#  '_14',
#  '_4',
#  '_5',
#  '_6',
#  '_7',
#  '_8',
#  '_9',
#  '__',
#  '___',
#  '__builtin__',
#  '__builtins__',
#  '__doc__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__spec__',
#  '_dh',
#  '_i',
#  '_i1',
#  '_i10',
#  '_i11',
#  '_i12',
#  '_i13',
#  '_i14',
#  '_i15',
#  '_i2',
#  '_i3',
#  '_i4',
#  '_i5',
#  '_i6',
#  '_i7',
#  '_i8',
#  '_i9',
#  '_ih',
#  '_ii',
#  '_iii',
#  '_oh',
#  'd',
#  'exit',
#  'get_ipython',
#  'quit']

# %%
ls
# Out:
#  Volume in drive D is New Volume
#  Volume Serial Number is 2CF0-A63D
#
#  Directory of D:\Python uploads\TrainingGames\MontyHallProblem
#
# 17.10.2022 Ј.  15:17    <DIR>          .
# 17.10.2022 Ј.  15:17    <DIR>          ..
# 17.10.2022 Ј.  13:37    <DIR>          .idea
# 17.10.2022 Ј.  13:35    <DIR>          .ipynb_checkpoints
# 16.10.2022 Ј.  18:13             1я511 main.py
# 17.10.2022 Ј.  15:17             2я752 TrainingData.ipynb
# 16.10.2022 Ј.  14:16    <DIR>          venv
#                2 File(s)          4я263 bytes
#                5 Dir(s)  85я169я008я640 bytes free

# %%
import pandas as pd

# %%
df = pd.read_csv("jupiter_moons.csv")

# %%
df
# Out:
#     Unnamed: 0  Order[note 3] Label[note 4]          Name    Pronunciation  \
# 0            0              1           XVI         Metis        /ˈmiːtəs/
# 1            1              2            XV      Adrastea     /ædrəˈstiːə/
# 2            2              3             V      Amalthea  /æməlˈθiːə/[50]
# 3            3              4           XIV         Thebe        /ˈθiːbiː/
# 4            4              5             I           Io♠          /ˈaɪoʊ/
# ..         ...            ...           ...           ...              ...
# 75          75             76           XLI        Aoede‡       /eɪˈiːdiː/
# 76          76             77        XXVIII      Autonoe‡     /ɔːˈtɒnoʊiː/
# 77          77             78          XVII   Callirrhoe‡     /kəˈlɪroʊiː/
# 78          78             79           NaN  S/2003 J 23‡              NaN
# 79          79             80          XLIX         Kore‡        /ˈkɔːriː/
#
# ...

# %%
dir()
# Out:
# ['In',
#  'Out',
#  '_',
#  '_11',
#  '_14',
#  '_15',
#  '_19',
#  '_20',
#  '_21',
#  '_22',
#  '_23',
#  '_4',
#  '_5',
#  '_6',
#  '_7',
#  '_8',
#  '_9',
#  '__',
#  '___',
#  '__builtin__',
#  '__builtins__',
#  '__doc__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__spec__',
#  '_dh',
#  '_exit_code',
#  '_i',
#  '_i1',
#  '_i10',
#  '_i11',
#  '_i12',
#  '_i13',
#  '_i14',
#  '_i15',
#  '_i16',
#  '_i17',
#  '_i18',
#  '_i19',
#  '_i2',
#  '_i20',
#  '_i21',
#  '_i22',
#  '_i23',
#  '_i24',
#  '_i3',
#  '_i4',
#  '_i5',
#  '_i6',
#  '_i7',
#  '_i8',
#  '_i9',
#  '_ih',
#  '_ii',
#  '_iii',
#  '_oh',
#  'd',
#  'df',
#  'exit',
#  'get_ipython',
#  'pd',
#  'quit']
